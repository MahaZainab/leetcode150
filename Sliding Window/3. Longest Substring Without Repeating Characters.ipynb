# %% [markdown]
# # 3. Longest Substring Without Repeating Characters

# %% [markdown]
# ## Description:

# %% [markdown]
# Given a string s, find the length of the longest
# substring
#  without repeating characters.

# %% [markdown]
# ## Examples:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Constraints:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Solution:

# %% [markdown]
# There are multiple solutions  exists. First we will see the brute force approach.

# %%
s="abcabcabc"
print(len(s))
# Out:
# 9

# %%
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        res = 0
        for i in range(len(s)):
            charSet = set()
            for j in range(i, len(s)):
                if s[j] in charSet:
                    break
                charSet.add(s[j])
            res = max(res, len(charSet))
        return res

# %% [markdown]
# #### However, We will solve this using sliding window technique.

# %%
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        left=0
        result=0
        charSet=set()
        for right in range(len(s)):
            while s[right] in charSet:
                charSet.remove(s[left])
                left+=1
            charSet.add(s[right])
            result=max(result, right-left+1)
        return result

# %% [markdown]
# Time complexity:O(n)
# Space complexity:O(n)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### And here is the most optimal soltion with sliding  window approach

# %%
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        mp = {}
        l = 0
        res = 0
        
        for r in range(len(s)):
            if s[r] in mp:
                l = max(mp[s[r]] + 1, l)
            mp[s[r]] = r
            res = max(res, r - l + 1)
        return res
